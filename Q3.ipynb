# %% [markdown]
# ### q3 : Find and plot via pia chart the total number of patients of each disease (diagnosis) with respect to the gender(Female, Male)

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from matplotlib import pyplot

# %%
data=pd.read_csv('jsrt_metadata.csv')
data=data.dropna()
data
# Out:
#          study_id  subtlety  size age  gender       x       y      state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0  malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0     benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0  malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0     benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0  malignant
# ..            ...       ...   ...  ..     ...     ...     ...        ...
# 149  JPCLN150.png       1.0  15.0  51  Female  1544.0  1409.0  malignant
# 150  JPCLN151.png       1.0  14.0  37  Female  1520.0  1364.0  malignant
# 151  JPCLN152.png       1.0  10.0  56    Male  1323.0  1438.0     benign
# 152  JPCLN153.png       1.0  10.0  64    Male  1708.0  1122.0  malignant
# 153  JPCLN154.png       1.0   8.0  75  Female   660.0   688.0  malignant
#
#                position                     diagnosis
# ...

# %%
#male
data_male = data.loc[data["gender"] == "Male"]
data_male.groupby("diagnosis")["gender"].count().plot(kind = "pie", figsize = (6, 6),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
#female
df_female= data.loc[data["gender"] == "Female"]
df_female.groupby("diagnosis")["gender"].count().plot(kind = "pie", figsize = (6,6),autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
#all
count=data['gender'].value_counts()
print(count)
plt.pyplot.pie(data['gender'].value_counts(),shadow=True,labels=['Female','Male'],autopct='%1.1f%%'
              ,startangle=0)
# Out:
# Female    86
# Male      68
# Name: gender, dtype: int64
# ([<matplotlib.patches.Wedge at 0x1c8f73891f0>,
# ...
#  [Text(-0.20082687393573656, 1.0815121666930982, 'Female'),
#   Text(0.20082697519421214, -1.0815121478903247, 'Male')],
#  [Text(-0.10954193123767447, 0.5899157272871445, '55.8%'),
#   Text(0.10954198646957024, -0.5899157170310861, '44.2%')])
